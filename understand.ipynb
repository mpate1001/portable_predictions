# %%
import pandas as pd
crime_df=pd.read_csv("crime_data.csv")
crime_df.head()
# Out:
#    year                county  Violent_sum  Homicide_sum  ForRape_sum  \
# 0  2022        Alameda County      11125.0         158.0        691.0
# 1  2022    Los Angeles County      61016.0         739.0       3869.0
# 2  2022      San Diego County      12497.0         106.0        755.0
# 3  2022  San Francisco County       5456.0          56.0        311.0
# 4  2022      San Mateo County       2295.0          13.0        230.0
#
#    Robbery_sum  AggAssault_sum  Property_sum  Burglary_sum  VehicleTheft_sum  \
# 0       4528.0          5748.0       69271.0        7910.0           16672.0
# 1      17438.0         38970.0      244083.0       39799.0           57872.0
# 2       2664.0          8972.0       52736.0        7556.0           12215.0
# 3       2444.0          2645.0       48411.0        6006.0            6359.0
# 4        551.0          1501.0       15538.0        2344.0            2069.0
#
#    ...  ViolentClr_sum  HomicideClr_sum  ForRapeClr_sum  RobberyClr_sum  \
# ...

# %%
latest_crime = crime_df.loc[crime_df.groupby("county")["year"]]
latest_crime.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 latest_crime = crime_df.loc[crime_df.groupby("county")["year"]]
#       2 latest_crime.head()
#
# File c:\Python\Python310\lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Python\Python310\lib\site-packages\pandas\core\indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
# ...

# %%
crime_df['year'].unique()
# Out:
# array([2022])

# %%
latest_crime = crime_df.loc[crime_df.groupby("county")["year"].idxmax()].copy()
latest_crime
# Out:
#      year                  county  Violent_sum  Homicide_sum  ForRape_sum  \
# 0    2022          Alameda County      11125.0         158.0        691.0
# 44   2022           Amador County      26582.0         373.0       2174.0
# 208  2022            Butte County      12246.0          43.0        436.0
# 9    2022     Contra Costa County      44516.0         469.0       1230.0
# 35   2022           Fresno County       3042.0         688.0       3666.0
# 159  2022         Humboldt County      54109.0         291.0        482.0
# 122  2022         Imperial County      57935.0         326.0       2560.0
# 11   2022             Kern County      42230.0         352.0       1593.0
# 1    2022      Los Angeles County      61016.0         739.0       3869.0
# 50   2022            Marin County      44145.0         729.0       3638.0
# 108  2022         Mariposa County      23699.0         471.0       3209.0
# 126  2022        Mendocino County      10802.0         673.0       3120.0
# ...

# %%
crime_df.sort_values(by='county', ascending=True)
# Out:
#        year          county  Violent_sum  Homicide_sum  ForRape_sum  \
# 0      2022  Alameda County      11125.0         158.0        691.0
# 25193  2022  Alameda County      23820.0         228.0        858.0
# 3389   2022  Alameda County      52002.0         671.0        485.0
# 25184  2022  Alameda County      18564.0         369.0       3110.0
# 25168  2022  Alameda County      58623.0         599.0        238.0
# 25160  2022  Alameda County      22215.0         328.0       1720.0
# 25158  2022  Alameda County      15595.0         373.0       3240.0
# 3398   2022  Alameda County       8948.0         119.0       1779.0
# 3403   2022  Alameda County      27936.0         592.0       3839.0
# 25135  2022  Alameda County      54127.0         229.0       2268.0
# 25120  2022  Alameda County      32541.0         506.0       2786.0
# 25098  2022  Alameda County      39001.0         234.0       2264.0
# 3412   2022  Alameda County      26687.0         624.0       3319.0
# ...

# %%
latest_crime = crime_df.loc[crime_df.groupby("county")["year"].idxmax()].copy()
latest_crime
# Out:
#      year                  county  Violent_sum  Homicide_sum  ForRape_sum  \
# 0    2022          Alameda County      11125.0         158.0        691.0
# 44   2022           Amador County      26582.0         373.0       2174.0
# 208  2022            Butte County      12246.0          43.0        436.0
# 9    2022     Contra Costa County      44516.0         469.0       1230.0
# 35   2022           Fresno County       3042.0         688.0       3666.0
# 159  2022         Humboldt County      54109.0         291.0        482.0
# 122  2022         Imperial County      57935.0         326.0       2560.0
# 11   2022             Kern County      42230.0         352.0       1593.0
# 1    2022      Los Angeles County      61016.0         739.0       3869.0
# 50   2022            Marin County      44145.0         729.0       3638.0
# 108  2022         Mariposa County      23699.0         471.0       3209.0
# 126  2022        Mendocino County      10802.0         673.0       3120.0
# ...

# %%
import pandas as pd

data = {'Category': ['A', 'B', 'A', 'C', 'B', 'A'],
        'Value': [10, 15, 12, 20, 18, 11]}
df = pd.DataFrame(data)

# Group by 'Category' and calculate the sum of 'Value' for each category
grouped_data = df.groupby('Category').

print(grouped_data)
# Out:
#           Value
# Category
# A            12
# B            18
# C            20

# %%
df.sort_values(by='Value', ascending=True)
# Out:
#   Category  Value
# 0        A     10
# 5        A     11
# 2        A     12
# 1        B     15
# 4        B     18
# 3        C     20
